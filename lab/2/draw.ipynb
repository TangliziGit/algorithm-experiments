# %%
from matplotlib import pyplot as plt

backtrace={2:40000.0, 3:0.0, 4:40000.0, 5:0.0, 6:40000.0, 7:40000.0, 8:80000.0, 9:280000.0, 10:560000.0, 11:7400000.0, 12:5040000.0, 13:2.468E7, 14:9.76E7, 15:3.936E8, 16:7.6636E8, 17:8.066E8, 18:8.2788E8}
branch={2:240000.0, 3:40000.0, 4:40000.0, 5:120000.0, 6:280000.0, 7:200000.0, 8:360000.0, 9:440000.0, 10:400000.0, 11:7320000.0, 12:480000.0, 13:1.284E7, 14:6.252E7, 15:2.272E7, 16:9.228E7, 17:4.854E8, 18:5.588E8}
branch_ppt={2:360000.0, 3:80000.0, 4:280000.0, 5:120000.0, 6:600000.0, 7:400000.0, 8:840000.0, 9:1560000.0, 10:2800000.0, 11:1.1992E8, 12:2.7952E8, 13:4.5388E8, 14:9.1388E8, 15: 1.1388E9}

plt.figure(figsize=(8, 4))
plt.plot(list(backtrace.keys()), list(backtrace.values()), label="Backtrace")
plt.plot(list(branch.keys()), list(branch.values()), label="Branch&Bound(RestMinCost)")
plt.plot(list(branch_ppt.keys()), list(branch_ppt.values()), label="Branch&Bound(TwoMinCost)")

plt.legend(loc="upper left")

plt.xlabel('Number of city')
plt.ylabel('Time costed (ms)')
plt.title('Backtracing and B&B Algorithms Difference on TSP')
plt.show()
